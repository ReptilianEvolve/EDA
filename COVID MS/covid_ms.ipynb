# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Data import and basic exploration

# %%
df = pd.read_csv('/home/ee/Documents/EDA/COVID MS/COVID.csv',decimal=',')
df.head()
# Out:
#               Unnamed: 0        Unnamed: 1        Unnamed: 2  \
# 0                Protein  Accession Number      Protein Name
# 1  sp|Q9HC84|MUC5B_HUMAN            Q9HC84          Mucin-5B
# 2  sp|P0DUB6|AMY1A_HUMAN            P0DUB6  Alpha-amylase 1A
# 3   sp|P02768|ALBU_HUMAN            P02768           Albumin
# 4    sp|P01024|CO3_HUMAN            P01024     Complement C3
#
#              Unnamed: 3   Unnamed: 4   Unnamed: 5     Unnamed: 6  \
# 0  Peptides per protein  Mean COVID+  Mean COVID-  Median COVID+
# 1                    15  0.016954643  0.010572587    0.013943032
# 2                    15  0.367665954  0.439566402    0.371972714
# 3                    14  0.095880099  0.172018646    0.117508475
# 4                    14  0.001509969  0.002236927    0.001635604
#
#       Unnamed: 7   Unnamed: 8   Unnamed: 9                  Unnamed: 10  \
# 0  Median COVID-   %CV COVID+   %CV COVID-  Mann-Whitney U Test p value
# ...

# %%
df = df.rename(columns=df.iloc[0]).drop(df.index[0]) #rename header
df.columns
# Out:
# Index(['Protein', 'Accession Number', 'Protein Name', 'Peptides per protein',
#        'Mean COVID+', 'Mean COVID-', 'Median COVID+', 'Median COVID-',
#        '%CV COVID+', '%CV COVID-', 'Mann-Whitney U Test p value',
#        'Fold Change', 'Comp. 1', 'Comp. 2', 'Comp. 3', 'Comp. 4', 'Comp. 5'],
#       dtype='object')

# %% [markdown]
# # Feature Selection

# %%
df.columns
# Out:
# Index(['Protein', 'Accession Number', 'Protein Name', 'Peptides per protein',
#        'Mean COVID+', 'Mean COVID-', 'Median COVID+', 'Median COVID-',
#        '%CV COVID+', '%CV COVID-', 'Mann-Whitney U Test p value',
#        'Fold Change', 'Comp. 1', 'Comp. 2', 'Comp. 3', 'Comp. 4', 'Comp. 5'],
#       dtype='object')

# %%
df.shape
# Out:
# (642, 17)

# %%
missing_info = pd.DataFrame(df.isnull().sum().sort_values()).reset_index() #number of empty row values
missing_info.rename(columns={'index':'col_name',0:'null_count'},inplace=True)
missing_info
# Out:
#                        col_name  null_count
# 0                       Protein           0
# 1                       Comp. 3           0
# 2                       Comp. 2           0
# 3                       Comp. 1           0
# 4                   Fold Change           0
# 5   Mann-Whitney U Test p value           0
# 6                    %CV COVID-           0
# 7                       Comp. 4           0
# 8                    %CV COVID+           0
# 9                 Median COVID+           0
# 10                  Mean COVID-           0
# 11                  Mean COVID+           0
# 12         Peptides per protein           0
# 13                 Protein Name           0
# 14             Accession Number           0
# 15                Median COVID-           0
# 16                      Comp. 5           0

# %%
df_vip = df.loc[:,['Comp. 1', 'Comp. 2', 'Comp. 3', 'Comp. 4', 'Comp. 5']].astype(np.float64)
df_vip.dtypes
# Out:
# Comp. 1    float64
# Comp. 2    float64
# Comp. 3    float64
# Comp. 4    float64
# Comp. 5    float64
# dtype: object

# %%
df_vip.isnull()
# Out:
#      Comp. 1  Comp. 2  Comp. 3  Comp. 4  Comp. 5
# 1      False    False    False    False    False
# 2      False    False    False    False    False
# 3      False    False    False    False    False
# 4      False    False    False    False    False
# 5      False    False    False    False    False
# 6      False    False    False    False    False
# 7      False    False    False    False    False
# 8      False    False    False    False    False
# 9      False    False    False    False    False
# 10     False    False    False    False    False
# 11     False    False    False    False    False
# 12     False    False    False    False    False
# 13     False    False    False    False    False
# 14     False    False    False    False    False
# 15     False    False    False    False    False
# 16     False    False    False    False    False
# 17     False    False    False    False    False
# 18     False    False    False    False    False
# ...

# %%
vip = df_vip.mean(axis=1,numeric_only=True,skipna=True).round(decimals=3)
vip = pd.DataFrame(vip,columns=['vip'])
vip
# Out:
#        vip
# 1    1.153
# 2    0.819
# 3    1.193
# 4    1.130
# 5    1.228
# 6    2.084
# 7    1.831
# 8    1.065
# 9    1.192
# 10   0.926
# 11   0.398
# 12   0.471
# 13   1.269
# 14   0.959
# 15   0.534
# 16   0.235
# 17   0.262
# 18   0.141
# 19   0.591
# 20   1.695
# 21   0.524
# 22   0.306
# 23   0.348
# 24   0.806
# 25   0.985
# 26   1.588
# 27   0.463
# 28   1.136
# 29   0.850
# 30   0.828
# 31   0.704
# 32   0.276
# 33   0.876
# 34   0.981
# 35   0.928
# 36   1.301
# 37   0.287
# 38   0.473
# 39   0.790
# 40   0.858
# 41   0.470
# 42   1.255
# 43   1.546
# 44   0.623
# 45   0.211
# 46   1.145
# 47   0.455
# 48   0.417
# 49   0.320
# 50   0.696
# 51   1.325
# 52   0.884
# 53   1.318
# 54   0.864
# 55   1.244
# 56   0.485
# 57   0.703
# 58   0.636
# 59   0.553
# 60   0.281
# 61   0.917
# 62   0.358
# 63   0.710
# 64   0.791
# 65   1.492
# 66   0.444
# 67   1.827
# 68   0.119
# 69   0.287
# 70   1.550
# 71   1.419
# 72   1.318
# 73   1.127
# 74   0.547
# 75   1.157
# ...

# %%
df_vip['vip'] = df.mean(axis=1,numeric_only=True,skipna=True).round(decimals=3)
df_vip.head()
#df.describe
# Out:
#    Comp. 1  Comp. 2  Comp. 3  Comp. 4  Comp. 5  vip
# 1  1.09890  1.17190  1.16650  1.16470  1.16500  NaN
# 2  0.73269  0.84262  0.83978  0.83971  0.83947  NaN
# 3  1.19150  1.19240  1.19450  1.19450  1.19440  NaN
# 4  1.10060  1.13690  1.13800  1.13660  1.13640  NaN
# 5  1.23320  1.22790  1.22740  1.22590  1.22590  NaN

# %%
df['Mean_COVID'] = df[['Mean COVID+','Mean COVID-']].mean(numeric_only=None)
df.head(10)
# Out:
# /tmp/ipykernel_6399/484491208.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Mean_COVID'] = df[['Mean COVID+','Mean COVID-']].mean(numeric_only=None)
#                   Protein Accession Number  \
# 1   sp|Q9HC84|MUC5B_HUMAN           Q9HC84
# 2   sp|P0DUB6|AMY1A_HUMAN           P0DUB6
# 3    sp|P02768|ALBU_HUMAN           P02768
# 4     sp|P01024|CO3_HUMAN           P01024
# 5    sp|P01833|PIGR_HUMAN           P01833
# 6    sp|P01023|A2MG_HUMAN           P01023
# 7    sp|P02788|TRFL_HUMAN           P02788
# 8   sp|A8K2U0|A2ML1_HUMAN           A8K2U0
# 9   sp|Q9Y6R7|FCGBP_HUMAN           Q9Y6R7
# 10   sp|P02787|TRFE_HUMAN           P02787
#
#                             Protein Name Peptides per protein  Mean COVID+  \
# 1                               Mucin-5B                   15  0.016954643
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Missing Value imputation

# %% [markdown]
# # Binning

# %% [markdown]
# # Variable Derivation

# %% [markdown]
# # Variable Segmentation

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Behavior Osbservation

# %% [markdown]
# # Insight Derivation

# %% [markdown]
# # Visualization
